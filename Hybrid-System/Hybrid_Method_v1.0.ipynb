# %%
import numpy as np
import pandas as pd

# %%
papers_df = pd.read_json('Papers_Metadata_6K.json')
users_df = pd.read_json('users.json')
ratings_df = pd.read_json('User_Ratings.json')

# %%
papers_df.head()
# Out:
#                                               author  day            id  \
# 0  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1  1802.00209v1
# 1  [{'name': 'Ji Young Lee'}, {'name': 'Franck De...   12  1603.03827v1
# 2  [{'name': 'Iulian Vlad Serban'}, {'name': 'Tim...    2  1606.00776v2
# 3  [{'name': 'Sebastian Ruder'}, {'name': 'Joachi...   23  1705.08142v2
# 4  [{'name': 'Iulian V. Serban'}, {'name': 'Chinn...    7  1709.02349v2
#
#                                                 link  month  \
# 0  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 1  [{'rel': 'alternate', 'href': 'http://arxiv.or...      3
# 2  [{'rel': 'alternate', 'href': 'http://arxiv.or...      6
# 3  [{'rel': 'alternate', 'href': 'http://arxiv.or...      5
# 4  [{'rel': 'alternate', 'href': 'http://arxiv.or...      9
#
#                                              summary  \
# 0  We propose an architecture for VQA which utili...
# 1  Recent approaches based on artificial neural n...
# 2  We introduce the multiresolution recurrent neu...
# 3  Multi-task learning is motivated by the observ...
# 4  We present MILABOT: a deep reinforcement learn...
#
#                                                  tag  \
# 0  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 1  [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
# 2  [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
# 3  [{'term': 'stat.ML', 'scheme': 'http://arxiv.o...
# 4  [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
#
#                                                title  year
# 0  Dual Recurrent Attention Units for Visual Ques...  2018
# 1  Sequential Short-Text Classification with Recu...  2016
# 2  Multiresolution Recurrent Neural Networks: An ...  2016
# 3  Learning what to share between loosely related...  2017
# 4              A Deep Reinforcement Learning Chatbot  2017

# %%
users_df.head()
# Out:
#    userID     Location   Age
# 0       1          nyc  NULL
# 1       2     stockton    18
# 2       3       moscow  NULL
# 3       4        porto    17
# 4       5  farnborough  NULL

# %%
merge_df = pd.merge(ratings_df, users_df, on='userID')

# %%
merge_df = pd.merge(merge_df, papers_df, on='id')

# %%
merge_df.head()
# Out:
#    userID            id  paperRating        Location Age  \
# 0     112  1802.00209v1            6     mexico city  32
# 1      21  1802.00209v1            8  ferrol / spain  46
# 2      21  1802.00209v1            9  ferrol / spain  46
# 3      21  1802.00209v1           10  ferrol / spain  46
# 4      21  1802.00209v1            6  ferrol / spain  46
#
#                                               author  day  \
# 0  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
# 1  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
# 2  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
# 3  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
# 4  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
#
#                                                 link  month  \
# 0  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 1  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 2  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 3  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 4  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
#
#                                              summary  \
# 0  We propose an architecture for VQA which utili...
# 1  We propose an architecture for VQA which utili...
# 2  We propose an architecture for VQA which utili...
# 3  We propose an architecture for VQA which utili...
# 4  We propose an architecture for VQA which utili...
#
#                                                  tag  \
# 0  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 1  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 2  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 3  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 4  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
#
#                                                title  year
# 0  Dual Recurrent Attention Units for Visual Ques...  2018
# 1  Dual Recurrent Attention Units for Visual Ques...  2018
# 2  Dual Recurrent Attention Units for Visual Ques...  2018
# 3  Dual Recurrent Attention Units for Visual Ques...  2018
# 4  Dual Recurrent Attention Units for Visual Ques...  2018

# %%
merge_df.drop_duplicates(subset=['userID','id'],inplace=True)

# %%
merge_df.head()
# Out:
#    userID            id  paperRating              Location   Age  \
# 0     112  1802.00209v1            6           mexico city    32
# 1      21  1802.00209v1            8        ferrol / spain    46
# 5      92  1802.00209v1            4  castellar del valles    20
# 7      52  1802.00209v1            6          braunschweig  NULL
# 8      74  1802.00209v1            2             amsterdam    30
#
#                                               author  day  \
# 0  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
# 1  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
# 5  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
# 7  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
# 8  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1
#
#                                                 link  month  \
# 0  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 1  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 5  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 7  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 8  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
#
#                                              summary  \
# 0  We propose an architecture for VQA which utili...
# 1  We propose an architecture for VQA which utili...
# 5  We propose an architecture for VQA which utili...
# 7  We propose an architecture for VQA which utili...
# 8  We propose an architecture for VQA which utili...
#
#                                                  tag  \
# 0  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 1  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 5  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 7  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 8  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
#
#                                                title  year
# 0  Dual Recurrent Attention Units for Visual Ques...  2018
# 1  Dual Recurrent Attention Units for Visual Ques...  2018
# 5  Dual Recurrent Attention Units for Visual Ques...  2018
# 7  Dual Recurrent Attention Units for Visual Ques...  2018
# 8  Dual Recurrent Attention Units for Visual Ques...  2018

# %%
from sklearn.preprocessing import OneHotEncoder
encode = OneHotEncoder(sparse=True)
item_features=encode.fit_transform(merge_df[['paperRating','id']])

# %%
item_features
# Out:
# <1787x1009 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3574 stored elements in Compressed Sparse Row format>

# %%
from lightfm.data import Dataset
paper_dataset=Dataset()
paper_dataset.fit(merge_df.userID.values,merge_df.id.values,item_features = merge_df['paperRating'].values)
# fit ratings, paper id and paper features to the model
# Out:
# C:\Users\veyso\anaconda3\envs\recommendation\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn('LightFM was compiled without OpenMP support. '

# %%
item_sub = merge_df[['id', 'summary']]
item_tuples = [tuple(x) for x in item_sub.values]

user_sub = merge_df[['userID', 'id', 'paperRating']]
user_tuples = [tuple(x) for x in user_sub.values]

# %%
(interactions, weights) = paper_dataset.build_interactions(user_tuples)
interactions
# Out:
# <200x999 sparse matrix of type '<class 'numpy.int32'>'
# 	with 1787 stored elements in COOrdinate format>

# %%
from lightfm.cross_validation import random_train_test_split
train, test = random_train_test_split(interactions, test_percentage=0.2, random_state=np.random.RandomState(seed=111))

# %%
from lightfm import LightFM
# Define a new model instance
model = LightFM(loss='warp',
                no_components=20)

# Fit the hybrid model, remember to pass in item features.
model = model.fit(train,item_features=item_features,epochs=10,num_threads=4)

# %%
from lightfm.evaluation import auc_score
# Don't forget the pass in the item features again!
train_auc = auc_score(model,train,item_features=item_features).mean()
print('Hybrid training set AUC: %s' % train_auc)
# Out:
# Hybrid training set AUC: 0.9462883

# %%
test_auc = auc_score(model,test,train_interactions=train,item_features=item_features).mean()
print('Hybrid test set AUC: %s' % test_auc)
# Out:
# Hybrid test set AUC: 0.7689488

# %%
#retriving the mappings of paper id
item_ids = list(paper_dataset.mapping()[0].values())

# %%
#make predictions, noted the user_ids is not the mapped userid, need to transform back to the original userid
pred = model.predict(user_ids=10,item_ids=list(paper_dataset.mapping()[2].values()))
l=list(zip(list(paper_dataset.mapping()[2].keys()),list(pred)))

# %%
pred_df = pd.DataFrame(l,columns = ['paper_id','recommendation_scores'])
pred_df = pred_df.sort_values("recommendation_scores",ascending=False)
pred_df.head()
# Out:
#          paper_id  recommendation_scores
# 713  1707.03017v5               1.748573
# 980  1512.04860v1               1.282389
# 623  1506.02078v2               0.865425
# 544  1608.00218v1               0.807027
# 602  1509.04265v2               0.236985

# %%
recommend_df = pd.DataFrame(columns=merge_df.columns)

# %%
for x in range(0,5):
    recommend_df = recommend_df.append(merge_df.loc[merge_df.id == pred_df.iloc[x]['paper_id']])

# %%
recommend_df
# Out:
#      userID            id paperRating     Location   Age  \
# 1713     85  1707.03017v5           7       london    41
# 1980     11  1512.04860v1           1    melbourne    14
# 1618    191  1506.02078v2           2       berlin    40
# 1524    194  1608.00218v1           3  lake forest  NULL
# 1594    192  1509.04265v2           2    sunnyvale  NULL
#
#                                                  author day  \
# 1713  [{'name': 'Ethan Perez'}, {'name': 'Harm de Vr...  10
# 1980  [{'name': 'Marc G. Bellemare'}, {'name': 'Geor...  15
# 1618  [{'name': 'Andrej Karpathy'}, {'name': 'Justin...   5
# 1524  [{'name': 'Ilija Ilievski'}, {'name': 'Jiashi ...  31
# 1594  [{'name': 'Gabriel Prat Masramon'}, {'name': '...  12
#
#                                                    link month  \
# 1713  [{'rel': 'alternate', 'href': 'http://arxiv.or...     7
# 1980  [{'rel': 'alternate', 'href': 'http://arxiv.or...    12
# 1618  [{'rel': 'alternate', 'href': 'http://arxiv.or...     6
# 1524  [{'rel': 'alternate', 'href': 'http://arxiv.or...     7
# 1594  [{'rel': 'alternate', 'href': 'http://arxiv.or...     9
#
#                                                 summary  \
# 1713  Achieving artificial visual reasoning - the ab...
# 1980  This paper introduces new optimality-preservin...
# 1618  Recurrent Neural Networks (RNNs), and specific...
# 1524  Recently, several optimization methods have be...
# 1594  Feature weighting algorithms try to solve a pr...
#
#                                                     tag  \
# 1713  [{'term': 'cs.CV', 'scheme': 'http://arxiv.org...
# 1980  [{'term': 'cs.AI', 'scheme': 'http://arxiv.org...
# 1618  [{'term': 'cs.LG', 'scheme': 'http://arxiv.org...
# 1524  [{'term': 'cs.LG', 'scheme': 'http://arxiv.org...
# 1594  [{'term': 'cs.LG', 'scheme': 'http://arxiv.org...
#
#                                                   title  year
# 1713    Learning Visual Reasoning Without Strong Priors  2017
# 1980  Increasing the Action Gap: New Operators for R...  2015
# 1618   Visualizing and Understanding Recurrent Networks  2015
# 1524  Hyperparameter Transfer Learning through Surro...  2016
# 1594  Double Relief with progressive weighting function  2015

# %%
# checking what user 1 has rated previously
merge_df[merge_df.userID == 1].head(10)
# Out:
#       userID            id  paperRating Location   Age  \
# 314        1  1709.08878v1            5      nyc  NULL
# 361        1  1606.00776v2            7      nyc  NULL
# 468        1  1604.04378v1            1      nyc  NULL
# 602        1  1504.00923v1            5      nyc  NULL
# 1119       1  1603.06127v4            1      nyc  NULL
# 1173       1  1610.06454v2            5      nyc  NULL
# 1226       1  1706.02490v1            7      nyc  NULL
# 1227       1  1606.08282v3            4      nyc  NULL
# 1228       1  1602.04484v5            7      nyc  NULL
# 1229       1   1302.6452v1            3      nyc  NULL
#
#                                                  author  day  \
# 314   [{'name': 'Kelvin Guu'}, {'name': 'Tatsunori B...   26
# 361   [{'name': 'Iulian Vlad Serban'}, {'name': 'Tim...    2
# 468   [{'name': 'Shengxian Wan'}, {'name': 'Yanyan L...   15
# 602   [{'name': 'Fred Richardson'}, {'name': 'Dougla...    3
# 1119  [{'name': 'Petr Baudiš'}, {'name': 'Jan Pichl'...   19
# 1173  [{'name': 'Tsendsuren Munkhdalai'}, {'name': '...   20
# 1226  [{'name': 'Karla Stepanova'}, {'name': 'Matej ...    8
# 1227  [{'name': 'Hamid Dadkhahi'}, {'name': 'Marco F...   27
# 1228  [{'name': 'David P. Helmbold'}, {'name': 'Phil...   14
# 1229  [{'name': 'Jing Lei'}, {'name': 'Alessandro Ri...   26
#
#                                                    link  month  \
# 314   [{'rel': 'alternate', 'href': 'http://arxiv.or...      9
# 361   [{'rel': 'alternate', 'href': 'http://arxiv.or...      6
# 468   [{'rel': 'alternate', 'href': 'http://arxiv.or...      4
# 602   [{'rel': 'alternate', 'href': 'http://arxiv.or...      4
# 1119  [{'rel': 'alternate', 'href': 'http://arxiv.or...      3
# 1173  [{'rel': 'alternate', 'href': 'http://arxiv.or...     10
# 1226  [{'rel': 'alternate', 'href': 'http://arxiv.or...      6
# 1227  [{'rel': 'related', 'href': 'http://dx.doi.org...      6
# 1228  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 1229  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
#
#                                                 summary  \
# 314   We propose a new generative model of sentences...
# 361   We introduce the multiresolution recurrent neu...
# 468   Semantic matching, which aims to determine the...
# 602   Learned feature representations and sub-phonem...
# 1119  We review the task of Sentence Pair Scoring, p...
# 1173  Hypothesis testing is an important cognitive p...
# 1226  Humans and animals are constantly exposed to a...
# 1227  This paper proposes an out-of-sample extension...
# 1228  We analyze dropout in deep networks with recti...
# 1229  This paper applies conformal prediction techni...
#
#                                                     tag  \
# 314   [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
# 361   [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
# 468   [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
# 602   [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
# 1119  [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
# 1173  [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
# 1226  [{'term': 'cs.NE', 'scheme': 'http://arxiv.org...
# 1227  [{'term': 'stat.ML', 'scheme': 'http://arxiv.o...
# 1228  [{'term': 'cs.LG', 'scheme': 'http://arxiv.org...
# 1229  [{'term': 'stat.ML', 'scheme': 'http://arxiv.o...
#
#                                                   title  year
# 314          Generating Sentences by Editing Prototypes  2017
# 361   Multiresolution Recurrent Neural Networks: An ...  2016
# 468   Match-SRNN: Modeling the Recursive Matching St...  2016
# 602   A Unified Deep Neural Network for Speaker and ...  2015
# 1119  Sentence Pair Scoring: Towards Unified Framewo...  2016
# 1173  Reasoning with Memory Augmented Neural Network...  2016
# 1226  Where is my forearm? Clustering of body parts ...  2017
# 1227  Out-of-Sample Extension for Dimensionality Red...  2016
# 1228  Surprising properties of dropout in deep networks  2016
# 1229  A Conformal Prediction Approach to Explore Fun...  2013
