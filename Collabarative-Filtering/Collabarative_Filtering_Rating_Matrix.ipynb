# %%
import numpy as np
import pandas as pd
from scipy.stats import sem, t
from scipy import mean
import seaborn as sns
from scipy.spatial.distance import hamming

# %%
papers_df = pd.read_json('Papers_Metadata_6K.json')
users_df = pd.read_json('Users.json')
ratings_df = pd.read_json('User_Ratings.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-7e79c35613ff> in <module>
#       1 papers_df = pd.read_json('Papers_Metadata_6K.json')
# ----> 2 users_df = pd.read_json('Users.json')
#       3 ratings_df = pd.read_json('User_Ratings.json')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in read(self)
#     729             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     730         else:
# --> 731             obj = self._get_object_parser(self.data)
#     732         self.close()
#     733         return obj
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     751         obj = None
#     752         if typ == "frame":
# --> 753             obj = FrameParser(json, **kwargs).parse()
#     754
#     755         if typ == "series" or obj is None:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in parse(self)
#     855
#     856         else:
# --> 857             self._parse_no_numpy()
#     858
#     859         if self.obj is None:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1087         if orient == "columns":
#    1088             self.obj = DataFrame(
# -> 1089                 loads(json, precise_float=self.precise_float), dtype=None
#    1090             )
#    1091         elif orient == "split":
#
# ValueError: Expected object or value

# %%
papers_df.head()

# %%
users_df.head()

# %%
ratings_df.head()

# %%
merge_df = pd.merge(ratings_df, users_df, on='userID')

# %%
merge_df.head()

# %%
merge_df = pd.merge(merge_df, papers_df, on='id')

# %%
merge_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e2540e51d387> in <module>
# ----> 1 merge_df.head()
#
# NameError: name 'merge_df' is not defined

# %%
merge_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3bf5db72517e> in <module>
# ----> 1 merge_df.shape
#
# NameError: name 'merge_df' is not defined

# %%
# drop out the user id that is null
merge_df = merge_df[pd.notnull(merge_df['userID'])]

# drop out the paper id that is null
merge_df = merge_df[pd.notnull(merge_df['id'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4bac7542c634> in <module>
#       1 # drop out the user id that is null
# ----> 2 merge_df = merge_df[pd.notnull(merge_df['userID'])]
#       3
#       4 # drop out the paper id that is null
#       5 merge_df = merge_df[pd.notnull(merge_df['id'])]
#
# NameError: name 'merge_df' is not defined

# %%
merge_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3bf5db72517e> in <module>
# ----> 1 merge_df.shape
#
# NameError: name 'merge_df' is not defined

# %%
merge_df = merge_df.drop(['Location', 'Age', 'author', 'day',
                   'link', 'month', 'summary', 'tag',
                   'title', 'year'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-44fc7d87a644> in <module>
# ----> 1 merge_df = merge_df.drop(['Location', 'Age', 'author', 'day',
#       2                    'link', 'month', 'summary', 'tag',
#       3                    'title', 'year'], axis=1)
#
# NameError: name 'merge_df' is not defined

# %%
merge_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e2540e51d387> in <module>
# ----> 1 merge_df.head()
#
# NameError: name 'merge_df' is not defined

# %%
merge_df[(merge_df.userID == 10) & (merge_df.paperRating > 5)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7d7402741f17> in <module>
# ----> 1 merge_df[(merge_df.userID == 10) & (merge_df.paperRating > 5)]
#
# NameError: name 'merge_df' is not defined

# %%
userItemRatingMatrix = pd.pivot_table(merge_df, values='paperRating',
                                    index=['userID'], columns=['id'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-34fcf5c00fdf> in <module>
# ----> 1 userItemRatingMatrix = pd.pivot_table(merge_df, values='paperRating',
#       2                                     index=['userID'], columns=['id'])
#
# NameError: name 'merge_df' is not defined

# %%
confidence = 0.95
data = ratings_per_isbn['count']

n = len(data)
m = mean(data)
std_err = sem(data)
h = std_err * t.ppf((1 + confidence) / 2, n - 1)

start = m - h
print (start)
ax = sns.distplot(ratings_per_isbn['count'])
ax2 = ax.twinx()
sns.boxplot(x=ratings_per_isbn['count'], ax=ax2)
ax2.set(ylim=(-0.5, 10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-029ea665e900> in <module>
#       1 confidence = 0.95
# ----> 2 data = ratings_per_isbn['count']
#       3
#       4 n = len(data)
#       5 m = mean(data)
#
# NameError: name 'ratings_per_isbn' is not defined
