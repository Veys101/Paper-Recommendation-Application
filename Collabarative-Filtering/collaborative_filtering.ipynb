# %%
import numpy as np
import pandas as pd

# %%
papers_df = pd.read_json('Papers_Metadata_6K.json')

papers_df.head()
# Out:
#                                               author  day            id  \
# 0  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1  1802.00209v1
# 1  [{'name': 'Ji Young Lee'}, {'name': 'Franck De...   12  1603.03827v1
# 2  [{'name': 'Iulian Vlad Serban'}, {'name': 'Tim...    2  1606.00776v2
# 3  [{'name': 'Sebastian Ruder'}, {'name': 'Joachi...   23  1705.08142v2
# 4  [{'name': 'Iulian V. Serban'}, {'name': 'Chinn...    7  1709.02349v2
#
#                                                 link  month  \
# 0  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 1  [{'rel': 'alternate', 'href': 'http://arxiv.or...      3
# 2  [{'rel': 'alternate', 'href': 'http://arxiv.or...      6
# 3  [{'rel': 'alternate', 'href': 'http://arxiv.or...      5
# 4  [{'rel': 'alternate', 'href': 'http://arxiv.or...      9
#
#                                              summary  \
# 0  We propose an architecture for VQA which utili...
# 1  Recent approaches based on artificial neural n...
# ...

# %%
users_df =pd.read_json("users.json")
users_df.head()
# Out:
#    User-ID     Location   Age
# 0        1          nyc  NULL
# 1        2     stockton    18
# 2        3       moscow  NULL
# 3        4        porto    17
# 4        5  farnborough  NULL

# %%
ratings_df =pd.read_json("ratings.json")
ratings_df.head()
# Out:
#    userID       paperID  paperRating
# 0     112  1802.00209v1            6
# 1      21  1603.03827v1            9
# 2      12  1606.00776v2            6
# 3      92  1705.08142v2            2
# 4      52  1709.02349v2            7

# %%
combine_book_rating = pd.merge(ratings_df, papers_df, on='id')
columns = ['author', 'day']
combine_book_rating = combine_book_rating.drop(columns, axis=1)
combine_book_rating.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-51c8b09cf506> in <module>
# ----> 1 combine_book_rating = pd.merge(ratings_df, papers_df, on='id')
#       2 columns = ['author', 'day']
#       3 combine_book_rating = combine_book_rating.drop(columns, axis=1)
#       4 combine_book_rating.head()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
