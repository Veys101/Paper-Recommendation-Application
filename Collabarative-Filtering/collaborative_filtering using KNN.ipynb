# %%
import numpy as np
import pandas as pd

# %%
papers_df = pd.read_json('Papers_Metadata_6K.json')

papers_df.head()
# Out:
#                                               author  day            id  \
# 0  [{'name': 'Ahmed Osman'}, {'name': 'Wojciech S...    1  1802.00209v1
# 1  [{'name': 'Ji Young Lee'}, {'name': 'Franck De...   12  1603.03827v1
# 2  [{'name': 'Iulian Vlad Serban'}, {'name': 'Tim...    2  1606.00776v2
# 3  [{'name': 'Sebastian Ruder'}, {'name': 'Joachi...   23  1705.08142v2
# 4  [{'name': 'Iulian V. Serban'}, {'name': 'Chinn...    7  1709.02349v2
#
#                                                 link  month  \
# 0  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 1  [{'rel': 'alternate', 'href': 'http://arxiv.or...      3
# 2  [{'rel': 'alternate', 'href': 'http://arxiv.or...      6
# 3  [{'rel': 'alternate', 'href': 'http://arxiv.or...      5
# 4  [{'rel': 'alternate', 'href': 'http://arxiv.or...      9
#
#                                              summary  \
# 0  We propose an architecture for VQA which utili...
# 1  Recent approaches based on artificial neural n...
# ...

# %%
users_df =pd.read_json("users.json")
users_df.head()
# Out:
#    User-ID     Location   Age
# 0        1          nyc  NULL
# 1        2     stockton    18
# 2        3       moscow  NULL
# 3        4        porto    17
# 4        5  farnborough  NULL

# %%
ratings_df =pd.read_json("ratings.json")
ratings_df.head()
# Out:
#    userID            id  paperRating
# 0     112  1802.00209v1            6
# 1      21  1603.03827v1            9
# 2      12  1606.00776v2            6
# 3      92  1705.08142v2            2
# 4      52  1709.02349v2            7

# %%
combine_papers_rating = pd.merge(ratings_df, papers_df, on='id')
columns = ['author', 'day']
combine_papers_rating = combine_papers_rating.drop(columns, axis=1)
combine_papers_rating.head()
# Out:
#    userID            id  paperRating  \
# 0     112  1802.00209v1            6
# 1      21  1603.03827v1            9
# 2      12  1606.00776v2            6
# 3      92  1705.08142v2            2
# 4      52  1709.02349v2            7
#
#                                                 link  month  \
# 0  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 1  [{'rel': 'alternate', 'href': 'http://arxiv.or...      3
# 2  [{'rel': 'alternate', 'href': 'http://arxiv.or...      6
# 3  [{'rel': 'alternate', 'href': 'http://arxiv.or...      5
# 4  [{'rel': 'alternate', 'href': 'http://arxiv.or...      9
#
#                                              summary  \
# 0  We propose an architecture for VQA which utili...
# 1  Recent approaches based on artificial neural n...
# 2  We introduce the multiresolution recurrent neu...
# 3  Multi-task learning is motivated by the observ...
# 4  We present MILABOT: a deep reinforcement learn...
#
# ...

# %%
combine_papers_rating = combine_papers_rating.dropna(axis = 0, subset = ['title'])

papers_ratingCount = (combine_papers_rating.
     groupby(by = ['title'])['paperRating'].
     count().
     reset_index().
     rename(columns = {'paperRating': 'totalRatingCount'})
     [['title', 'totalRatingCount']]
    )
papers_ratingCount.head()
# Out:
#                                                title  totalRatingCount
# 0  'Almost Sure' Chaotic Properties of Machine Le...                 1
# 1  10,000+ Times Accelerated Robust Subset Select...                 1
# 2  3D-PRNN: Generating Shape Primitives with Recu...                 1
# 3  A Behavior Analysis-Based Game Bot Detection A...                 1
# 4  A Benchmarking Environment for Reinforcement L...                 1

# %%
rating_with_totalRatingCount = combine_papers_rating.merge(papers_ratingCount, left_on = 'title', right_on = 'title', how = 'left')
rating_with_totalRatingCount.head()
# Out:
#    userID            id  paperRating  \
# 0     112  1802.00209v1            6
# 1      21  1603.03827v1            9
# 2      12  1606.00776v2            6
# 3      92  1705.08142v2            2
# 4      52  1709.02349v2            7
#
#                                                 link  month  \
# 0  [{'rel': 'alternate', 'href': 'http://arxiv.or...      2
# 1  [{'rel': 'alternate', 'href': 'http://arxiv.or...      3
# 2  [{'rel': 'alternate', 'href': 'http://arxiv.or...      6
# 3  [{'rel': 'alternate', 'href': 'http://arxiv.or...      5
# 4  [{'rel': 'alternate', 'href': 'http://arxiv.or...      9
#
#                                              summary  \
# 0  We propose an architecture for VQA which utili...
# 1  Recent approaches based on artificial neural n...
# 2  We introduce the multiresolution recurrent neu...
# 3  Multi-task learning is motivated by the observ...
# 4  We present MILABOT: a deep reinforcement learn...
#
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(papers_ratingCount['totalRatingCount'].describe())
# Out:
# count   999.000
# mean      1.000
# std       0.000
# min       1.000
# 25%       1.000
# 50%       1.000
# 75%       1.000
# max       1.000
# Name: totalRatingCount, dtype: float64

# %%
print(papers_ratingCount['totalRatingCount'].quantile(np.arange(.9, 1, .01)))
# Out:
# 0.900   1.000
# 0.910   1.000
# 0.920   1.000
# 0.930   1.000
# 0.940   1.000
# 0.950   1.000
# 0.960   1.000
# 0.970   1.000
# 0.980   1.000
# 0.990   1.000
# Name: totalRatingCount, dtype: float64

# %%
popularity_threshold = 50
rating_popular_papers = rating_with_totalRatingCount.query('totalRatingCount >= @popularity_threshold')
rating_popular_papers.head()
# Out:
# Empty DataFrame
# Columns: [userID, id, paperRating, link, month, summary, tag, title, year, totalRatingCount]
# Index: []

# %%
rating_popular_papers.shape
# Out:
# (0, 10)

# %%
combined = rating_popular_papers.merge(users, left_on = 'userID', right_on = 'userID', how = 'left')

us_canada_user_rating = combined[combined['Location'].str.contains("usa|canada")]
us_canada_user_rating=us_canada_user_rating.drop('Age', axis=1)
us_canada_user_rating.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-5c9b5116772b> in <module>
# ----> 1 combined = rating_popular_papers.merge(users, left_on = 'userID', right_on = 'userID', how = 'left')
#       2
#       3 us_canada_user_rating = combined[combined['Location'].str.contains("usa|canada")]
#       4 us_canada_user_rating=us_canada_user_rating.drop('Age', axis=1)
#       5 us_canada_user_rating.head()
#
# NameError: name 'users' is not defined

# %%
combined = rating_popular_book.merge(users, left_on = 'userID', right_on = 'userID', how = 'left')

us_canada_user_rating = combined[combined['Location'].str.contains("usa|canada")]
us_canada_user_rating=us_canada_user_rating.drop('Age', axis=1)
us_canada_user_rating.head()
