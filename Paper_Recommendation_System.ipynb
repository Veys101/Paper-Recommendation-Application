# %%
import pandas as pd
import numpy as np

# %%
papers_df = pd.read_json('arxivData.json',usecols=['author','day','id','link','month','summary','tag','title','year'],dtype={'author': 'str','day':'int32','id':'int32','link':'str','month':'int32','summary':'str','tag':'str','title':'str','year':'int32'})
papers_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b68b518ea6d4> in <module>
# ----> 1 papers_df = pd.read_json('arxivData.json',usecols=['author','day','id','link','month','summary','tag','title','year'],dtype={'author': 'str','day':'int32','id':'int32','link':'str','month':'int32','summary':'str','tag':'str','title':'str','year':'int32'})
#       2 papers_df.head()
#
# ~\anaconda3\envs\recommendation\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# TypeError: read_json() got an unexpected keyword argument 'usecols'
